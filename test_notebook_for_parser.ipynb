# %% [markdown]
# # Notebook to build code to extract words from a file

# %% [markdown]
# ### Since we only want words I think regex will be the best bet

# %%
import re

# %%
filename = './alice30.txt'

# %%
def GetWordsFromFile(filename):
    data = open(filename, 'r')
    text = data.read().lower()
    words = re.findall(r'[a-zA-Z]+(?:(?:\-|\')[a-zA-Z]+)?', text)
    text = None
    word_dict = {}
    for word in words:
        if word in word_dict:
            word_dict[word] = word_dict[word] + 1
        else:
            word_dict[word] = 1    
    return word_dict

# %%
def WriteWordsToFile(filename, word_dict):
    data = open(filename, 'w')
    for word in word_dict:
        entry = '%s,%i\n' % (word, word_dict[word])
        data.write(entry)
    data.close()
    return None

# %%
word_dict = GetWordsFromFile(filename)

# %%
WriteWordsToFile('./words.txt', word_dict)

# %%
word_dict
# Out:
# {'secondly': 2,
#  'pardon': 6,
#  'saves': 1,
#  'knelt': 1,
#  'four': 6,
#  'sleep': 6,
#  'hanging': 3,
#  'ringlets': 2,
#  'oldest': 1,
#  'hate': 2,
#  'assembled': 2,
#  'forget': 2,
#  'whose': 2,
#  'lory': 7,
#  'paris': 2,
#  'blacking': 1,
#  'presents': 2,
#  'under': 16,
#  'inwards': 1,
#  'sorry': 1,
#  'worth': 4,
#  'music': 3,
#  'rise': 1,
#  'every': 12,
#  'seals': 1,
#  'fireplace': 1,
#  'school': 5,
#  'prize': 1,
#  'wooden': 1,
#  'pinch': 2,
#  'persisted': 2,
#  'oblong': 1,
#  'writing-desk': 1,
#  'favoured': 1,
#  'leaders': 1,
#  'tired': 7,
#  'feathers': 1,
#  'elegant': 1,
#  'likely': 5,
#  'louder': 1,
#  'machines': 1,
#  'shining': 1,
#  'even': 19,
#  'meekly': 2,
#  'hide': 1,
#  'pace': 1,
#  'solemn': 3,
#  'thunder': 1,
#  'near': 15,
#  'poison': 3,
#  'above': 3,
#  'conduct': 1,
#  'rat-hole': 1,
#  'new': 5,
#  'ever': 21,
#  'told': 6,
#  'half-past': 2,
#  'never': 47,
#  'wrapping': 1,
#  'here': 51,
#  'met': 3,
#  'protection': 1,
#  'hers': 4,
#  'cardboard': 1,
#  'shriek': 5,
#  'rabbit-hole': 4,
#  'daughter': 1,
#  'leaves': 6,
#  'changed': 8,
#  'mustard-mine': 1,
#  'swam': 5,
#  "i'd": 11,
#  'smoke': 1,
#  "i'm": 59,
#  'twenty-four': 2,
#  'changes': 2,
#  'ventured': 4,
#  'golden': 7,
#  'ground': 5,
#  'explained': 1,
#  'angrily': 9,
#  'feelings': 2,
#  'brought': 3,
#  'patience': 1,
#  'moral': 8,
#  'guests': 3,
#  'drowned': 1,
#  'punching': 1,
#  'spoke': 17,
#  'would': 83,
#  'arms': 6,
#  'insult': 1,
#  'call': 9,
#  'therefore': 1,
#  'leant': 1,
#  "caterpillar's": 1,
#  'tell': 32,
#  'breathe': 3,
#  'peeping': 1,
#  'evening': 5,
#  'hurt': 3,
#  'grief': 1,
#  'glass': 10,
#  'excellent': 2,
#  'adjourn': 1,
#  "game's": 1,
#  'hold': 10,
#  'must': 44,
#  'me': 68,
#  'locked': 1,
#  'room': 13,
#  'work': 8,
#  'dodo': 13,
#  'worm': 1,
#  'roof': 6,
#  'obstacle': 1,
#  'elbow': 3,
#  'my': 58,
#  'shook': 9,
#  'rosetree': 1,
#  'quiver': 1,
#  'serpent': 9,
#  'give': 12,
#  'unjust': 1,
#  'flung': 1,
#  'frighten': 1,
#  'want': 9,
#  'extraordinary': 2,
#  'keep': 11,
#  'dutchess': 1,
#  'suet': 1,
#  'end': 18,
#  'turn': 10,
#  'complaining': 1,
#  'agony': 1,
#  'returning': 1,
#  'how': 68,
#  'hot': 5,
#  'answer': 9,
#  'truthful': 1,
#  'poker': 1,
#  'flustered': 1,
#  'mouths': 4,
#  'lad': 1,
#  'ladder': 1,
#  'after': 42,
#  'caucus-race': 3,
#  'wrong': 5,
#  'jumping': 4,
#  'lay': 4,
#  'curiosity': 5,
#  'law': 2,
#  'lap': 2,
#  'attempt': 1,
#  'guinea-pig': 2,
#  "head's": 1,
#  'childhood': 1,
#  'wink': 2,
#  'wriggling': 1,
#  'green': 4,
#  'aloud': 5,
#  'order': 3,
#  'wind': 2,
#  'wine': 2,
#  'executed': 6,
#  'dreamed': 1,
#  'over': 40,
#  'london': 1,
#  'mabel': 4,
#  'sea-shore': 1,
#  'before': 38,
#  'chatte': 1,
#  'fit': 3,
#  'somewhere': 3,
#  'lefthand': 2,
#  'fix': 1,
#  'writing': 4,
#  'better': 14,
#  'fig': 1,
#  'glanced': 1,
#  'croquet': 6,
#  'weeks': 1,
#  'overcome': 1,
#  'then': 94,
#  'them': 88,
#  'slate': 3,
#  'safe': 2,
#  'nibbled': 2,
#  'break': 2,
#  'caterpillar': 27,
#  'they': 131,
#  'interrupt': 1,
#  'one': 103,
#  'bank': 3,
#  'pegs': 1,
#  'grammar': 1,
#  'meat': 1,
#  'alternately': 1,
#  'herald': 1,
#  'eleventh': 1,
#  'roast': 1,
#  'each': 8,
#  'went': 83,
#  'side': 17,
#  'bone': 1,
#  'mean': 10,
#  'calmly': 1,
#  'race-course': 1,
#  'telescope': 3,
#  'series': 1,
#  'dodged': 1,
#  'vote': 1,
#  'taught': 4,
#  'forgot': 2,
#  'flock': 1,
#  'sounds': 4,
#  'reminding': 1,
#  'velvet': 1,
#  'frying-pan': 1,
#  'sighing': 3,
#  'fellows': 1,
#  'content': 1,
#  'laid': 2,
#  'millennium': 1,
#  'surprise': 5,
#  'size': 13,
#  'splashed': 1,
#  'stamping': 2,
#  'turning': 12,
#  "you're": 23,
#  'writing-desks': 1,
#  'given': 1,
#  'free': 3,
#  'uglification': 2,
#  'whereupon': 1,
#  'mallets': 1,
#  'wanted': 4,
#  'telescopes': 1,
#  'enormous': 1,
#  'ate': 1,
#  'shelves': 1,
#  'writhing': 1,
#  'cackled': 1,
#  'messages': 2,
#  'days': 4,
#  'pence': 1,
#  'hopeless': 1,
#  'arrived': 1,
#  'loud': 6,
#  'bite': 2,
#  'enjoy': 1,
#  'already': 2,
#  'dunce': 1,
#  'curiouser': 2,
#  'encouraging': 2,
#  'hearing': 4,
#  'wash': 2,
#  'another': 22,
#  'thoughtfully': 4,
#  'thick': 1,
#  'awfully': 1,
#  'xii': 1,
#  'top': 8,
#  'girls': 3,
#  'airs': 1,
#  'master': 3,
#  'too': 26,
#  'wildly': 2,
#  'legs': 3,
#  'bitter': 1,
#  'dogs': 3,
#  "rabbit's": 4,
#  'listen': 7,
#  'consented': 1,
#  'ceiling': 1,
#  'solemnly': 4,
#  'took': 24,
#  'positively': 1,
#  'character': 1,
#  'begins': 4,
#  'distance': 8,
#  'coward': 1,
#  'tree': 5,
#  'second': 4,
#  'seated': 1,
#  'shower': 2,
#  'matter': 9,
#  'splendidly': 1,
#  'exclaimed': 6,
#  'flame': 1,
#  'friend': 3,
#  'askance': 1,
#  'feeling': 7,
#  'chrysalis': 1,
#  'ran': 16,
#  'shyly': 1,
#  'modern': 1,
#  'mind': 11,
#  'mine': 9,
#  'sorrow': 2,
#  'talking': 17,
#  'manner': 2,
#  'seen': 15,
#  'seem': 8,
#  'tells': 2,
#  'eels': 1,
#  'strength': 1,
#  'thoroughly': 2,
#  'eagerly': 8,
#  'subjects': 1,
#  'doors': 2,
#  'laughed': 2,
#  'sweet-tempered': 1,
#  'gravy': 1,
#  'nobody': 8,
#  'though': 12,
#  'regular': 2,
#  'mouth': 10,
#  'plenty': 2,
#  'grave': 3,
#  'zealand': 1,
#  'alarm': 2,
#  'm': 4,
#  'dog': 2,
#  'ridiculous': 1,
#  'sun': 2,
#  'notion': 3,
#  'came': 40,
#  'decidedly': 4,
#  'saying': 15,
#  'currants': 1,
#  'pardoned': 1,
#  'pope': 1,
#  'lewis': 1,
#  'queen': 68,
#  'sage': 1,
#  'ending': 1,
#  'attempts': 1,
#  'queer': 11,
#  'earth': 4,
#  'toast': 1,
#  'busy': 2,
#  'spite': 1,
#  'explain': 10,
#  'folded': 3,
#  'sugar': 1,
#  'deepest': 1,
#  'disgust': 1,
#  'do': 81,
#  'cartwheels': 1,
#  'squeaking': 2,
#  'stop': 6,
#  'coast': 1,
#  'frowning': 4,
#  'shutting': 2,
#  'cushion': 2,
#  'altogether': 5,
#  'nasty': 1,
#  'learned': 1,
#  'bat': 3,
#  'nicely': 2,
#  'anxiously': 14,
#  "mayn't": 1,
#  'shape': 1,
#  'licking': 1,
#  'twice': 5,
#  'bad': 2,
#  'softly': 1,
#  'three-legged': 2,
#  'explanations': 1,
#  'ears': 5,
#  'blew': 2,
#  'fair': 1,
#  'depends': 1,
#  'decided': 3,
#  'flashed': 1,
#  'cattle': 1,
#  'miserable': 2,
#  'mournfully': 1,
#  'best': 12,
#  'subject': 6,
#  'pebbles': 2,
#  'said': 462,
#  'away': 25,
#  "there's": 24,
#  'finger': 5,
#  'pie-crust': 1,
#  'sorts': 3,
#  'claws': 2,
#  'we': 30,
#  'interrupting': 2,
#  'terms': 1,
#  'confusion': 5,
#  'weak': 2,
#  'however': 20,
#  'camomile': 1,
#  'twinkling': 4,
#  'drew': 5,
#  'picking': 2,
#  'improve': 1,
#  'pity': 3,
#  'received': 1,
#  'accident': 2,
#  'country': 1,
#  'ill': 2,
#  'cup': 2,
#  'adventures': 7,
#  'edgar': 1,
#  'jury-box': 4,
#  'players': 4,
#  'games': 1,
#  'after-time': 1,
#  'treacle': 5,
#  'argue': 1,
#  'asked': 17,
#  'tone': 40,
#  'appeared': 8,
#  'royal': 2,
#  'lullaby': 1,
#  'height': 5,
#  'wider': 1,
#  'beheaded': 3,
#  'speak': 15,
#  'shouting': 2,
#  'tarts': 7,
#  'three': 26,
#  'been': 38,
#  'quarrelling': 2,
#  'chimneys': 1,
#  'much': 51,
#  'axis': 1,
#  'interest': 1,
#  'schoolroom': 1,
#  'expected': 1,
#  'lovely': 2,
#  'threw': 2,
#  'dry': 8,
#  'life': 11,
#  'wags': 1,
#  'mushroom': 8,
#  'arm-in': 1,
#  'prison': 1,
#  'grunt': 1,
#  'uncommon': 1,
#  'child': 10,
#  'catch': 4,
#  'doth': 3,
#  'teapot': 1,
#  'has': 7,
#  'lessen': 1,
#  'tastes': 1,
#  'air': 14,
#  'ugly': 2,
#  'lizard': 5,
#  'neat': 1,
#  'viii': 1,
#  'stopping': 1,
#  'voice': 48,
#  'mistake': 3,
#  'remembering': 1,
#  'ix': 1,
#  'seven': 6,
#  'fourteenth': 1,
#  'played': 1,
#  'is': 108,
#  'it': 530,
#  'iv': 1,
#  'ii': 1,
#  'gloomily': 1,
#  'clinging': 1,
#  'in': 367,
#  'mouse': 42,
#  'if': 96,
#  'grown': 7,
#  'growl': 3,
#  'severity': 1,
#  'things': 30,
#  'make': 27,
#  'linked': 1,
#  'forehead': 2,
#  'barrowful': 2,
#  'unfortunate': 3,
#  'vegetable': 1,
#  'plates': 2,
#  'several': 4,
#  'couple': 1,
#  'bells': 1,
#  'fairly': 1,
#  'slate-pencil': 1,
#  'tops': 1,
#  'hand': 20,
#  'delight': 3,
#  'marched': 1,
#  'dozing': 1,
#  'opportunity': 8,
#  "he'll": 1,
#  'thoughts': 2,
#  'kid': 5,
#  'butter': 8,
#  'hearth': 1,
#  'kept': 13,
#  'thy': 1,
#  'matters': 2,
#  'settled': 3,
#  'humble': 1,
#  'rome': 2,
#  'humbly': 2,
#  'impertinent': 1,
#  'hearts': 8,
#  'the': 1637,
#  'yours': 3,
#  'left': 14,
#  "she'll": 3,
#  'just': 52,
#  'sentence': 6,
#  'sleepy': 5,
#  'atheling': 1,
#  'verses': 4,
#  'farther': 1,
#  'yes': 13,
#  'yer': 4,
#  'yet': 25,
#  'adding': 1,
#  'spectacles': 3,
#  'unable': 1,
#  'hjckrrh': 1,
#  'had': 178,
#  'grumbled': 1,
#  "ma'am": 1,
#  'belongs': 2,
#  'easy': 2,
#  'arm-chair': 1,
#  'save': 1,
#  'hat': 1,
#  'gave': 15,
#  'boxed': 1,
#  'possible': 1,
#  'possibly': 3,
#  'dreamy': 1,
#  'flamingoes': 2,
#  'afore': 1,
#  'judge': 4,
#  'burnt': 1,
#  'shoulder': 4,
#  'sorrows': 1,
#  'appearing': 1,
#  'uncivil': 1,
#  'seaside': 1,
#  'alice': 386,
#  'quadrille': 4,
#  'officer': 1,
#  'night': 3,
#  'hung': 1,
#  'introduce': 2,
#  'towards': 1,
#  'right': 31,
#  'old': 19,
#  'deal': 12,
#  'people': 13,
#  'sends': 1,
#  'crown': 3,
#  'somehow': 1,
#  'dead': 4,
#  'clubs': 1,
#  'escape': 4,
#  'dear': 29,
#  'straightening': 1,
#  'bore': 1,
#  'goldfish': 2,
#  'creep': 1,
#  'confusing': 3,
#  'denies': 1,
#  'for': 153,
#  'bottom': 4,
#  'purple': 1,
#  'ear': 6,
#  'everything': 12,
#  'asking': 5,
#  'shakespeare': 1,
#  'denied': 2,
#  'serpents': 3,
#  'beating': 2,
#  'christmas': 1,
#  'pinched': 2,
#  'knew': 14,
#  'burn': 2,
#  'disappeared': 2,
#  'lamps': 1,
#  'losing': 1,
#  'bowing': 1,
#  'permitted': 1,
#  'takes': 2,
#  'wept': 1,
#  'theirs': 1,
#  'newspapers': 1,
#  'choke': 1,
#  'o': 3,
#  'dinner': 2,
#  'despair': 1,
#  'sluggard': 1,
#  'raised': 2,
#  'sob': 1,
#  'wasting': 2,
#  'puzzle': 1,
#  'delighted': 2,
#  'cauldron': 2,
#  'son': 1,
#  'down': 102,
#  'respectable': 1,
#  'bats': 4,
#  'balanced': 1,
#  'frightened': 7,
#  "animal's": 1,
#  'cleared': 1,
#  'crowd': 4,
#  'wag': 1,
#  'sneezing': 6,
#  'fight': 2,
#  'derision': 1,
#  'morcar': 2,
#  'overhead': 1,
#  'was': 357,
#  'happy': 1,
#  'fork': 1,
#  'head': 49,
#  'waistcoat': 1,
#  'form': 1,
#  'offer': 2,
#  'attempted': 1,
#  'becoming': 1,
#  'hot-tempered': 1,
#  'back': 38,
#  'failure': 1,
#  'hear': 14,
#  'heap': 1,
#  'boon': 1,
#  'removed': 2,
#  'true': 4,
#  'fainting': 1,
#  'flavour': 1,
#  "else's": 1,
#  'inside': 2,
#  'until': 5,
#  'scream': 2,
#  'unusually': 1,
#  'temper': 5,
#  'proud': 2,
#  'proved': 2,
#  'sticks': 1,
#  'screaming': 1,
#  'fury': 3,
#  'toss': 1,
#  'muscular': 1,
#  'drive': 2,
#  'howling': 3,
#  'guessed': 3,
#  'promised': 1,
#  'curious': 19,
#  'accounting': 1,
#  'floor': 3,
#  "moment's": 2,
#  'generally': 7,
#  'handed': 3,
#  'tis': 5,
#  'beheading': 1,
#  'setting': 1,
#  'holding': 3,
#  'tie': 1,
#  'vanished': 4,
#  'shrink': 1,
#  'saucepans': 1,
#  'picture': 1,
#  'pronounced': 1,
#  'ointment': 1,
#  'welcome': 1,
#  "let's": 5,
#  'skirt': 1,
#  'fell': 6,
#  'ridges': 1,
#  'bread-and': 5,
#  'inkstand': 1,
#  'unlocking': 1,
#  'died': 1,
#  'puss': 1,
#  'spades': 1,
#  'cheated': 1,
#  'salt': 2,
#  'together': 9,
#  'beds': 1,
#  'longed': 2,
#  "slates'll": 1,
#  'contemptuous': 1,
#  'time': 68,
#  'push': 1,
#  'treading': 2,
#  'managed': 4,
#  'remarkable': 2,
#  'whoever': 1,
#  'dance': 13,
#  'untwist': 1,
#  'fulcrum': 1,
#  'branches': 2,
#  'invent': 1,
#  'crocodile': 1,
#  'mile': 2,
#  'milk': 1,
#  'row': 2,
#  'certainly': 14,
#  'day-school': 1,
#  'father': 6,
#  'passage': 4,
#  'answered': 4,
#  'unpleasant': 2,
#  'terror': 1,
#  'circumstances': 1,
#  'jogged': 1,
#  'fancied': 2,
#  'brown': 2,
#  'made': 30,
#  'keeping': 2,
#  'hatter': 55,
#  'choice': 2,
#  'stays': 1,
#  'cook': 13,
#  'ma': 2,
#  'trouble': 6,
#  'exact': 1,
#  'feeble': 2,
#  'minute': 21,
#  'cool': 2,
#  'sighed': 5,
#  'presented': 1,
#  'did': 63,
#  'turns': 3,
#  'dig': 1,
#  'accidentally': 1,
#  'leave': 9,
#  'p': 1,
#  'settle': 1,
#  'quick': 2,
#  'teaching': 1,
#  'scaly': 1,
#  'round': 41,
#  "it'll": 8,
#  'prevent': 1,
#  'brave': 1,
#  'says': 4,
#  'tougher': 1,
#  'sigh': 4,
#  'sign': 1,
#  'cost': 1,
#  'dried': 1,
#  'eating': 1,
#  'helpless': 1,
#  'irritated': 1,
#  'appear': 2,
#  'croquet-ground': 3,
#  'axes': 1,
#  'lazily': 1,
#  'goes': 7,
#  'reply': 5,
#  'falling': 2,
#  'geography': 1,
#  'filled': 3,
#  'growls': 1,
#  'conger-eel': 1,
#  'jury': 17,
#  'partners': 1,
#  'honour': 4,
#  'v': 1,
#  'french': 4,
#  'water': 4,
#  'twentieth': 1,
#  'yards': 1,
#  "hadn't": 8,
#  'along': 6,
#  'change': 14,
#  'wait': 1,
#  'box': 4,
#  'sending': 2,
#  'impatiently': 5,
#  'lazy': 1,
#  'wherever': 2,
#  'gryphon': 55,
#  'trial': 7,
#  'usually': 2,
#  'shifting': 1,
#  'quarrel': 1,
#  'useful': 2,
#  'morals': 1,
#  'extra': 1,
#  'hopeful': 1,
#  'merely': 2,
#  'marked': 6,
#  'inquisitively': 1,
#  'fairy-tales': 1,
#  'barley-sugar': 1,
#  'swallowed': 1,
#  'stingy': 1,
#  'everybody': 8,
#  'driest': 1,
#  'angry': 5,
#  'visit': 1,
#  'only': 50,
#  'france': 1,
#  'live': 8,
#  'wood': 8,
#  'somersault': 1,
#  'wondering': 7,
#  'teeth': 1,
#  'today': 1,
#  'loving': 1,
#  'chapter': 12,
#  'entrance': 1,
#  'sharing': 1,
#  'afford': 1,
#  'flying': 1,
#  'teases': 1,
#  'ignorant': 1,
#  'oop': 7,
#  'doubled-up': 1,
#  'low-spirited': 1,
#  'fly': 3,
#  'deserved': 1,
#  'pretend': 1,
#  'longitude': 2,
#  'cat': 35,
#  'soup': 18,
#  'sour': 1,
#  'can': 35,
#  'growing': 11,
#  'making': 8,
#  'dispute': 2,
#  'laughter': 1,
#  'slightest': 1,
#  'heart': 2,
#  'crazy': 1,
#  'frontispiece': 1,
#  'nursing': 3,
#  'figure': 3,
#  'carroll': 1,
#  'confused': 4,
#  'paused': 1,
#  'heard': 30,
#  'chin': 7,
#  'dropped': 5,
#  'counting': 1,
#  'stole': 2,
#  'evidently': 1,
#  'pink': 1,
#  'winter': 1,
#  'fortunately': 1,
#  'buttered': 1,
#  'watching': 3,
#  'write': 6,
#  'till': 21,
#  'fourth': 1,
#  'stigand': 1,
#  'condemn': 1,
#  'may': 13,
#  'dive': 1,
#  'spot': 1,
#  'crashed': 1,
#  'birthday': 1,
#  'tipped': 1,
#  'mad': 15,
#  'such': 41,
#  'grow': 13,
#  'man': 5,
#  'scrambling': 1,
#  'natural': 4,
#  'remember': 14,
#  'succeeded': 3,
#  'whenever': 1,
#  'maybe': 2,
#  'daisies': 1,
#  'tale': 4,
#  "dinah's": 1,
#  'so': 151,
#  'crept': 1,
#  'offend': 1,
#  'pulled': 1,
#  'talk': 14,
#  'recognised': 1,
#  'shoes': 7,
#  'seeing': 1,
#  'indeed': 16,
#  'pointed': 1,
#  'canary': 1,
#  'years': 1,
#  'course': 25,
#  'quarrelled': 1,
#  'shake': 1,
#  'argued': 1,
#  'cold': 1,
#  'still': 13,
#  'owl': 3,
#  'birds': 10,
#  'limbs': 1,
#  'yawning': 2,
#  'thank': 4,
#  'curly': 1,
#  "he's": 3,
#  'interesting': 5,
#  'curls': 1,
#  "he'd": 1,
#  'civil': 3,
#  'window': 8,
#  'dreadfully': 6,
#  'thump': 2,
#  'ours': 1,
#  'into': 67,
#  'happened': 7,
#  'roses': 3,
#  'lonely': 2,
#  'tucked': 3,
#  'conversations': 1,
#  'natured': 1,
#  'to-night': 1,
#  'bound': 1,
#  'underneath': 1,
#  'tails': 3,
#  'soo': 7,
#  'half': 21,
#  'not': 145,
#  'now': 60,
#  'hall': 9,
#  'nor': 3,
#  'execute': 1,
#  'shouted': 9,
#  'name': 10,
#  'chuckled': 1,
#  'corners': 1,
#  'drop': 1,
#  'rock': 1,
#  'scolded': 1,
#  'entirely': 2,
#  'creature': 4,
#  'water-well': 1,
#  'em': 3,
#  'eh': 1,
#  'bursting': 1,
#  'beloved': 1,
#  'hurried': 11,
#  'goose': 2,
#  'catching': 2,
#  'begun': 7,
#  'year': 2,
#  'milk-jug': 1,
#  'happen': 8,
#  'worried': 1,
#  'giddy': 2,
#  'living': 2,
#  'canvas': 1,
#  'opened': 10,
#  'concert': 2,
#  'abide': 1,
#  'hastily': 16,
#  'looking': 31,
#  'seriously': 1,
#  'stupid': 6,
#  "shouldn't": 5,
#  'housemaid': 1,
#  'juror': 1,
#  'attended': 1,
#  'state': 1,
#  'quite': 55,
#  'bringing': 3,
#  'besides': 4,
#  'jelly-fish': 1,
#  'care': 4,
#  'advance': 3,
#  'beautify': 1,
#  'reasonable': 1,
#  'honest': 1,
#  'night-air': 1,
#  'thing': 49,
#  'place': 8,
#  'invitation': 2,
#  'think': 53,
#  'waited': 11,
#  'first': 51,
#  'sprawling': 1,
#  'arithmetic': 1,
#  'xi': 1,
#  'beauti': 1,
#  'spoken': 1,
#  "executioner's": 1,
#  'yourself': 10,
#  'merrily': 1,
#  'fast': 4,
#  'directly': 2,
#  'carry': 1,
#  'impossible': 3,
#  'ring': 2,
#  'open': 7,
#  'tomorrow': 1,
#  'cheerfully': 1,
#  'sheep': 1,
#  'little': 128,
#  ...}

# %%
def GetWordsFromFile(filename):
    data = open(filename, 'r')
    text = data.read()
    words = [word.lower() for word in re.findall(r'[a-zA-Z]+(?:\'[a-zA-Z]+)?', text)]
    text = None
    word_dict = {}
    for word in words:
        if word in word_dict:
            word_dict[word] = word_dict[word] + 1
        else:
            word_dict[word] = 1    
    return word_dict

# %%
re.findall(r'[a-zA-Z]+(?:(?:\-|\')[a-zA-Z]+)?', 'hello there i\'ll be coming soon what-the heck.')
# Out:
# ['hello', 'there', "i'll", 'be', 'coming', 'soon', 'what-the', 'heck']
